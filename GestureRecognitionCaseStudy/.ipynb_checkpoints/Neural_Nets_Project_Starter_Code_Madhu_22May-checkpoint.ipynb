# %% [markdown]
# # Gesture Recognition
# In this group project, you are going to build a 3D Conv model that will be able to predict the 5 gestures correctly. Please import the following libraries to get started.

# %%
import numpy as np
import os
from scipy.misc import imread, imresize
import datetime
import os

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
np.random.seed(30)
import random as rn
rn.seed(30)
from keras import backend as K
import tensorflow as tf
tf.set_random_seed(30)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %%
train_doc = np.random.permutation(open('./Project_data/train.csv').readlines())
val_doc = np.random.permutation(open('./Project_data/val.csv').readlines())
batch_size = 10 #experiment with the batch size

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
def generator(source_path, folder_list, batch_size):
    print( 'Source path = ', source_path, '; batch size =', batch_size)
    img_idx = [x for x in range(0, 30)] #create a list of image numbers you want to use for a particular video
    while True:
        t = np.random.permutation(folder_list)
        num_batches = len(t)//batch_size # calculate the number of batches
        for batch in range(num_batches): # we iterate over the number of batches
            batch_data = np.zeros((batch_size,x,y,z,3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    
                    image_resized=imresize(image,(120,120,3)) #image height and width is taken as 120
                    
                    batch_data[folder,idx,:,:,0] = (image_resized[:,:,0])/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = (image_resized[:,:,1])/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = (image_resized[:,:,2])/255 #normalise and feed in the image
                    
                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

        
        # write the code for the remaining data points which are left after full batches
        if (len(folder_list) != batch_size*num_batches):
            batch_size = len(folder_list) - (batch_size*num_batches)
            yield batch_data, batch_labels

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %%
curr_dt_time = datetime.datetime.now()
train_path = './Project_data/train'
val_path = './Project_data/val'
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
num_epochs = 10 # choose the number of epochs
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 10

# %% [markdown]
# ## Model
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation, Dropout
from keras.layers.convolutional import Conv3D, MaxPooling3D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras import optimizers

#write your model here

#Defining the filters and dense layers
F = [8,16,32,64]
D = [256, 128, 5]

# Input shape
I=(30,120,120,3) # (frames,num_rows,num_cols,channel)

#Model Definition for Conv3D
model = Sequential()

model.add(Conv3D(F[0], 
                 kernel_size=(3,3,3), 
                 input_shape=I,
                 padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Conv3D(F[1], 
                 kernel_size=(3,3,3), 
                 padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Conv3D(F[2], 
                 kernel_size=(1,3,3), 
                 padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(MaxPooling3D(pool_size=(2,2,2)))

model.add(Conv3D(F[3], 
                 kernel_size=(1,3,3), 
                 padding='same'))
model.add(Activation('relu'))
model.add(Dropout(0.25))

model.add(MaxPooling3D(pool_size=(2,2,2)))

#Flatten Layer
model.add(Flatten())

model.add(Dense(D[0], activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(D[1], activation='relu'))
model.add(Dropout(0.5))

#softmax
model.add(Dense(D[2], activation='softmax'))

# %% [markdown]
# Now that you have written the model, the next step is to `compile` the model. When you print the `summary` of the model, you'll see the total number of parameters you have to train.

# %%
from keras.optimizers import Adam
optimiser = Adam() #write your optimizer
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_1 (Conv3D)            (None, 30, 120, 120, 8)   656
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 30, 120, 120, 8)   32
# _________________________________________________________________
# activation_1 (Activation)    (None, 30, 120, 120, 8)   0
# _________________________________________________________________
# max_pooling3d_1 (MaxPooling3 (None, 15, 60, 60, 8)     0
# _________________________________________________________________
# conv3d_2 (Conv3D)            (None, 15, 60, 60, 16)    3472
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 15, 60, 60, 16)    64
# _________________________________________________________________
# activation_2 (Activation)    (None, 15, 60, 60, 16)    0
# _________________________________________________________________
# max_pooling3d_2 (MaxPooling3 (None, 7, 30, 30, 16)     0
# _________________________________________________________________
# conv3d_3 (Conv3D)            (None, 7, 30, 30, 32)     4640
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 7, 30, 30, 32)     128
# _________________________________________________________________
# activation_3 (Activation)    (None, 7, 30, 30, 32)     0
# _________________________________________________________________
# max_pooling3d_3 (MaxPooling3 (None, 3, 15, 15, 32)     0
# _________________________________________________________________
# conv3d_4 (Conv3D)            (None, 3, 15, 15, 64)     18496
# _________________________________________________________________
# activation_4 (Activation)    (None, 3, 15, 15, 64)     0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 3, 15, 15, 64)     0
# _________________________________________________________________
# max_pooling3d_4 (MaxPooling3 (None, 1, 7, 7, 64)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3136)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               803072
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 5)                 645
# =================================================================
# Total params: 864,101
# Trainable params: 863,989
# Non-trainable params: 112
# _________________________________________________________________
# None

# %% [markdown]
# Let us create the `train_generator` and the `val_generator` which will be used in `.fit_generator`.

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, cooldown=1, verbose=1) # write the REducelronplateau code here
callbacks_list = [checkpoint, LR]

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
x = 30 #Frame
y = 120 #rows
z = 120 #columns
batch_size = 10
num_epochs = 10
model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  ./Project_data/val ; batch size = 10
# Source path =  ./Project_data/train ; batch size = 10
# Epoch 1/10
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   del sys.path[0]
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:18: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# 67/67 [==============================] - 213s 3s/step - loss: 1.8594 - categorical_accuracy: 0.2478 - val_loss: 1.4446 - val_categorical_accuracy: 0.3400
#
# Epoch 00001: saving model to model_init_2020-05-2216_46_52.551350/model-00001-1.85937-0.24776-1.44462-0.34000.h5
# Epoch 2/10
# 67/67 [==============================] - 25s 377ms/step - loss: 1.5798 - categorical_accuracy: 0.3234 - val_loss: 1.7824 - val_categorical_accuracy: 0.2300
#
# Epoch 00002: saving model to model_init_2020-05-2216_46_52.551350/model-00002-1.57977-0.32338-1.78242-0.23000.h5
# Epoch 3/10
# 67/67 [==============================] - 26s 395ms/step - loss: 1.5580 - categorical_accuracy: 0.2637 - val_loss: 1.2575 - val_categorical_accuracy: 0.4300
#
# Epoch 00003: saving model to model_init_2020-05-2216_46_52.551350/model-00003-1.55802-0.26368-1.25750-0.43000.h5
# Epoch 4/10
# 67/67 [==============================] - 26s 393ms/step - loss: 1.5025 - categorical_accuracy: 0.3582 - val_loss: 1.3494 - val_categorical_accuracy: 0.4000
#
# Epoch 00004: saving model to model_init_2020-05-2216_46_52.551350/model-00004-1.50245-0.35821-1.34940-0.40000.h5
# Epoch 5/10
# 67/67 [==============================] - 27s 405ms/step - loss: 1.3598 - categorical_accuracy: 0.3930 - val_loss: 1.3961 - val_categorical_accuracy: 0.4300
#
# Epoch 00005: saving model to model_init_2020-05-2216_46_52.551350/model-00005-1.35977-0.39303-1.39612-0.43000.h5
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 6/10
# 67/67 [==============================] - 27s 406ms/step - loss: 1.2995 - categorical_accuracy: 0.4129 - val_loss: 1.1279 - val_categorical_accuracy: 0.5600
#
# Epoch 00006: saving model to model_init_2020-05-2216_46_52.551350/model-00006-1.29947-0.41294-1.12793-0.56000.h5
# Epoch 7/10
# 67/67 [==============================] - 26s 389ms/step - loss: 1.2467 - categorical_accuracy: 0.4129 - val_loss: 1.2893 - val_categorical_accuracy: 0.5400
#
# Epoch 00007: saving model to model_init_2020-05-2216_46_52.551350/model-00007-1.24672-0.41294-1.28933-0.54000.h5
# Epoch 8/10
# 67/67 [==============================] - 26s 387ms/step - loss: 1.1772 - categorical_accuracy: 0.4527 - val_loss: 1.0132 - val_categorical_accuracy: 0.5700
#
# Epoch 00008: saving model to model_init_2020-05-2216_46_52.551350/model-00008-1.17722-0.45274-1.01315-0.57000.h5
# Epoch 9/10
# 67/67 [==============================] - 28s 413ms/step - loss: 1.1488 - categorical_accuracy: 0.5721 - val_loss: 1.0091 - val_categorical_accuracy: 0.5800
#
# Epoch 00009: saving model to model_init_2020-05-2216_46_52.551350/model-00009-1.14879-0.57214-1.00914-0.58000.h5
# Epoch 10/10
# 67/67 [==============================] - 26s 393ms/step - loss: 1.1201 - categorical_accuracy: 0.5473 - val_loss: 1.0466 - val_categorical_accuracy: 0.6000
#
# Epoch 00010: saving model to model_init_2020-05-2216_46_52.551350/model-00010-1.12008-0.54726-1.04663-0.60000.h5

# %%
batch_size = 90
num_epochs = 20

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/20
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   del sys.path[0]
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:18: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# 8/8 [==============================] - 3s 420ms/step - loss: 0.9370 - categorical_accuracy: 0.5000 - val_loss: 1.2001 - val_categorical_accuracy: 0.6500
#
# Epoch 00001: saving model to model_init_2020-05-2216_46_52.551350/model-00001-0.93697-0.50000-1.20009-0.65000.h5
# Epoch 2/20
# 8/8 [==============================] - 4s 446ms/step - loss: 1.1174 - categorical_accuracy: 0.5833 - val_loss: 1.0812 - val_categorical_accuracy: 0.6500
#
# Epoch 00002: saving model to model_init_2020-05-2216_46_52.551350/model-00002-1.11739-0.58333-1.08117-0.65000.h5
# Epoch 3/20
# 8/8 [==============================] - 4s 460ms/step - loss: 1.1233 - categorical_accuracy: 0.4583 - val_loss: 1.1555 - val_categorical_accuracy: 0.4500
#
# Epoch 00003: saving model to model_init_2020-05-2216_46_52.551350/model-00003-1.12334-0.45833-1.15554-0.45000.h5
# Epoch 4/20
# 8/8 [==============================] - 4s 443ms/step - loss: 1.4688 - categorical_accuracy: 0.2917 - val_loss: 0.9605 - val_categorical_accuracy: 0.5500
#
# Epoch 00004: saving model to model_init_2020-05-2216_46_52.551350/model-00004-1.46883-0.29167-0.96048-0.55000.h5
# Epoch 5/20
# 8/8 [==============================] - 3s 389ms/step - loss: 1.1970 - categorical_accuracy: 0.5000 - val_loss: 0.9667 - val_categorical_accuracy: 0.6000
#
# Epoch 00005: saving model to model_init_2020-05-2216_46_52.551350/model-00005-1.19704-0.50000-0.96672-0.60000.h5
# Epoch 6/20
# 8/8 [==============================] - 4s 486ms/step - loss: 0.8858 - categorical_accuracy: 0.7500 - val_loss: 0.7711 - val_categorical_accuracy: 0.8000
#
# Epoch 00006: saving model to model_init_2020-05-2216_46_52.551350/model-00006-0.88576-0.75000-0.77112-0.80000.h5
# Epoch 7/20
# 8/8 [==============================] - 3s 357ms/step - loss: 1.1155 - categorical_accuracy: 0.3750 - val_loss: 0.9904 - val_categorical_accuracy: 0.6000
#
# Epoch 00007: saving model to model_init_2020-05-2216_46_52.551350/model-00007-1.11554-0.37500-0.99042-0.60000.h5
# Epoch 8/20
# 8/8 [==============================] - 3s 435ms/step - loss: 0.9585 - categorical_accuracy: 0.7500 - val_loss: 1.0032 - val_categorical_accuracy: 0.5000
#
# Epoch 00008: saving model to model_init_2020-05-2216_46_52.551350/model-00008-0.95853-0.75000-1.00316-0.50000.h5
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 9/20
# 8/8 [==============================] - 3s 409ms/step - loss: 1.0646 - categorical_accuracy: 0.4167 - val_loss: 1.1651 - val_categorical_accuracy: 0.5000
#
# Epoch 00009: saving model to model_init_2020-05-2216_46_52.551350/model-00009-1.06455-0.41667-1.16509-0.50000.h5
# Epoch 10/20
# 8/8 [==============================] - 3s 375ms/step - loss: 1.0826 - categorical_accuracy: 0.4167 - val_loss: 1.1923 - val_categorical_accuracy: 0.6500
#
# Epoch 00010: saving model to model_init_2020-05-2216_46_52.551350/model-00010-1.08264-0.41667-1.19229-0.65000.h5
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 11/20
# 8/8 [==============================] - 4s 446ms/step - loss: 1.0113 - categorical_accuracy: 0.5000 - val_loss: 0.9422 - val_categorical_accuracy: 0.6000
#
# Epoch 00011: saving model to model_init_2020-05-2216_46_52.551350/model-00011-1.01131-0.50000-0.94215-0.60000.h5
# Epoch 12/20
# 8/8 [==============================] - 3s 422ms/step - loss: 0.9184 - categorical_accuracy: 0.5417 - val_loss: 0.6949 - val_categorical_accuracy: 0.8500
#
# Epoch 00012: saving model to model_init_2020-05-2216_46_52.551350/model-00012-0.91841-0.54167-0.69486-0.85000.h5
# Epoch 13/20
# 8/8 [==============================] - 3s 426ms/step - loss: 1.0117 - categorical_accuracy: 0.5000 - val_loss: 0.7328 - val_categorical_accuracy: 0.8500
#
# Epoch 00013: saving model to model_init_2020-05-2216_46_52.551350/model-00013-1.01168-0.50000-0.73275-0.85000.h5
# Epoch 14/20
# 8/8 [==============================] - 3s 405ms/step - loss: 1.1103 - categorical_accuracy: 0.5000 - val_loss: 1.2920 - val_categorical_accuracy: 0.4500
#
# Epoch 00014: saving model to model_init_2020-05-2216_46_52.551350/model-00014-1.11028-0.50000-1.29202-0.45000.h5
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 15/20
# 8/8 [==============================] - 3s 394ms/step - loss: 0.8278 - categorical_accuracy: 0.6667 - val_loss: 0.8416 - val_categorical_accuracy: 0.7500
#
# Epoch 00015: saving model to model_init_2020-05-2216_46_52.551350/model-00015-0.82783-0.66667-0.84157-0.75000.h5
# Epoch 16/20
# 8/8 [==============================] - 3s 414ms/step - loss: 0.8189 - categorical_accuracy: 0.5833 - val_loss: 0.9907 - val_categorical_accuracy: 0.5000
#
# Epoch 00016: saving model to model_init_2020-05-2216_46_52.551350/model-00016-0.81886-0.58333-0.99069-0.50000.h5
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 17/20
# 8/8 [==============================] - 4s 440ms/step - loss: 0.9605 - categorical_accuracy: 0.6667 - val_loss: 0.6191 - val_categorical_accuracy: 0.7500
#
# Epoch 00017: saving model to model_init_2020-05-2216_46_52.551350/model-00017-0.96049-0.66667-0.61912-0.75000.h5
# Epoch 18/20
# 8/8 [==============================] - 3s 365ms/step - loss: 1.1023 - categorical_accuracy: 0.6250 - val_loss: 1.1639 - val_categorical_accuracy: 0.6500
#
# Epoch 00018: saving model to model_init_2020-05-2216_46_52.551350/model-00018-1.10229-0.62500-1.16391-0.65000.h5
# Epoch 19/20
# 8/8 [==============================] - 3s 409ms/step - loss: 0.9555 - categorical_accuracy: 0.5000 - val_loss: 1.1661 - val_categorical_accuracy: 0.5500
#
# Epoch 00019: saving model to model_init_2020-05-2216_46_52.551350/model-00019-0.95554-0.50000-1.16611-0.55000.h5
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 20/20
# 8/8 [==============================] - 3s 418ms/step - loss: 1.2255 - categorical_accuracy: 0.5417 - val_loss: 0.5825 - val_categorical_accuracy: 0.7500
#
# Epoch 00020: saving model to model_init_2020-05-2216_46_52.551350/model-00020-1.22550-0.54167-0.58249-0.75000.h5

# %%
batch_size = 90
num_epochs = 30

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   del sys.path[0]
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:18: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# Epoch 1/30
# 8/8 [==============================] - 4s 514ms/step - loss: 0.8209 - categorical_accuracy: 0.7917 - val_loss: 1.1017 - val_categorical_accuracy: 0.5500
#
# Epoch 00001: saving model to model_init_2020-05-2117_05_17.093187/model-00001-0.82093-0.79167-1.10167-0.55000.h5
# Epoch 2/30
# 8/8 [==============================] - 3s 397ms/step - loss: 1.0378 - categorical_accuracy: 0.5833 - val_loss: 0.7968 - val_categorical_accuracy: 0.8500
#
# Epoch 00002: saving model to model_init_2020-05-2117_05_17.093187/model-00002-1.03778-0.58333-0.79682-0.85000.h5
# Epoch 3/30
# 8/8 [==============================] - 3s 436ms/step - loss: 0.9208 - categorical_accuracy: 0.5833 - val_loss: 1.0112 - val_categorical_accuracy: 0.5000
#
# Epoch 00003: saving model to model_init_2020-05-2117_05_17.093187/model-00003-0.92080-0.58333-1.01122-0.50000.h5
# Epoch 4/30
# 8/8 [==============================] - 4s 456ms/step - loss: 0.7628 - categorical_accuracy: 0.6250 - val_loss: 1.0264 - val_categorical_accuracy: 0.5500
#
# Epoch 00004: saving model to model_init_2020-05-2117_05_17.093187/model-00004-0.76279-0.62500-1.02639-0.55000.h5
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# Epoch 5/30
# 8/8 [==============================] - 3s 371ms/step - loss: 0.9662 - categorical_accuracy: 0.6667 - val_loss: 0.8706 - val_categorical_accuracy: 0.7500
#
# Epoch 00005: saving model to model_init_2020-05-2117_05_17.093187/model-00005-0.96625-0.66667-0.87061-0.75000.h5
# Epoch 6/30
# 8/8 [==============================] - 3s 399ms/step - loss: 0.9208 - categorical_accuracy: 0.7083 - val_loss: 0.8204 - val_categorical_accuracy: 0.7500
#
# Epoch 00006: saving model to model_init_2020-05-2117_05_17.093187/model-00006-0.92083-0.70833-0.82039-0.75000.h5
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# Epoch 7/30
# 8/8 [==============================] - 3s 433ms/step - loss: 0.9686 - categorical_accuracy: 0.5833 - val_loss: 0.8723 - val_categorical_accuracy: 0.7000
#
# Epoch 00007: saving model to model_init_2020-05-2117_05_17.093187/model-00007-0.96859-0.58333-0.87229-0.70000.h5
# Epoch 8/30
# 8/8 [==============================] - 4s 438ms/step - loss: 0.8806 - categorical_accuracy: 0.6667 - val_loss: 0.8870 - val_categorical_accuracy: 0.7500
#
# Epoch 00008: saving model to model_init_2020-05-2117_05_17.093187/model-00008-0.88059-0.66667-0.88703-0.75000.h5
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# Epoch 9/30
# 8/8 [==============================] - 4s 438ms/step - loss: 1.0208 - categorical_accuracy: 0.5417 - val_loss: 0.9636 - val_categorical_accuracy: 0.6000
#
# Epoch 00009: saving model to model_init_2020-05-2117_05_17.093187/model-00009-1.02082-0.54167-0.96357-0.60000.h5
# Epoch 10/30
# 8/8 [==============================] - 3s 429ms/step - loss: 0.8638 - categorical_accuracy: 0.6667 - val_loss: 0.7980 - val_categorical_accuracy: 0.7500
#
# Epoch 00010: saving model to model_init_2020-05-2117_05_17.093187/model-00010-0.86383-0.66667-0.79805-0.75000.h5
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# Epoch 11/30
# 8/8 [==============================] - 3s 423ms/step - loss: 1.0013 - categorical_accuracy: 0.5417 - val_loss: 0.9906 - val_categorical_accuracy: 0.6500
#
# Epoch 00011: saving model to model_init_2020-05-2117_05_17.093187/model-00011-1.00131-0.54167-0.99063-0.65000.h5
# Epoch 12/30
# 8/8 [==============================] - 4s 471ms/step - loss: 0.8806 - categorical_accuracy: 0.6250 - val_loss: 0.9103 - val_categorical_accuracy: 0.6500
#
# Epoch 00012: saving model to model_init_2020-05-2117_05_17.093187/model-00012-0.88064-0.62500-0.91035-0.65000.h5
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# Epoch 13/30
# 8/8 [==============================] - 4s 490ms/step - loss: 1.0189 - categorical_accuracy: 0.5000 - val_loss: 1.0510 - val_categorical_accuracy: 0.6000
#
# Epoch 00013: saving model to model_init_2020-05-2117_05_17.093187/model-00013-1.01890-0.50000-1.05096-0.60000.h5
# Epoch 14/30
# 8/8 [==============================] - 3s 422ms/step - loss: 0.7681 - categorical_accuracy: 0.7500 - val_loss: 0.8607 - val_categorical_accuracy: 0.7000
#
# Epoch 00014: saving model to model_init_2020-05-2117_05_17.093187/model-00014-0.76808-0.75000-0.86074-0.70000.h5
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# Epoch 15/30
# 8/8 [==============================] - 3s 392ms/step - loss: 0.8216 - categorical_accuracy: 0.6667 - val_loss: 0.8086 - val_categorical_accuracy: 0.7000
#
# Epoch 00015: saving model to model_init_2020-05-2117_05_17.093187/model-00015-0.82157-0.66667-0.80863-0.70000.h5
# Epoch 16/30
# 8/8 [==============================] - 3s 385ms/step - loss: 1.2019 - categorical_accuracy: 0.4167 - val_loss: 0.6673 - val_categorical_accuracy: 0.8000
#
# Epoch 00016: saving model to model_init_2020-05-2117_05_17.093187/model-00016-1.20190-0.41667-0.66732-0.80000.h5
# Epoch 17/30
# 8/8 [==============================] - 3s 430ms/step - loss: 0.9008 - categorical_accuracy: 0.6667 - val_loss: 0.8935 - val_categorical_accuracy: 0.7000
#
# Epoch 00017: saving model to model_init_2020-05-2117_05_17.093187/model-00017-0.90075-0.66667-0.89347-0.70000.h5
# Epoch 18/30
# 8/8 [==============================] - 4s 488ms/step - loss: 0.7159 - categorical_accuracy: 0.8333 - val_loss: 1.0544 - val_categorical_accuracy: 0.6000
#
# Epoch 00018: saving model to model_init_2020-05-2117_05_17.093187/model-00018-0.71593-0.83333-1.05441-0.60000.h5
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# Epoch 19/30
# 8/8 [==============================] - 3s 407ms/step - loss: 0.9671 - categorical_accuracy: 0.5833 - val_loss: 0.9632 - val_categorical_accuracy: 0.7000
#
# Epoch 00019: saving model to model_init_2020-05-2117_05_17.093187/model-00019-0.96715-0.58333-0.96322-0.70000.h5
# Epoch 20/30
# 8/8 [==============================] - 3s 396ms/step - loss: 0.8556 - categorical_accuracy: 0.7500 - val_loss: 0.7655 - val_categorical_accuracy: 0.7500
#
# Epoch 00020: saving model to model_init_2020-05-2117_05_17.093187/model-00020-0.85557-0.75000-0.76549-0.75000.h5
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 7.629394893626795e-09.
# Epoch 21/30
# 8/8 [==============================] - 4s 510ms/step - loss: 1.0972 - categorical_accuracy: 0.5833 - val_loss: 1.0497 - val_categorical_accuracy: 0.6000
#
# Epoch 00021: saving model to model_init_2020-05-2117_05_17.093187/model-00021-1.09721-0.58333-1.04975-0.60000.h5
# Epoch 22/30
# 8/8 [==============================] - 3s 430ms/step - loss: 0.9867 - categorical_accuracy: 0.6250 - val_loss: 0.9235 - val_categorical_accuracy: 0.7000
#
# Epoch 00022: saving model to model_init_2020-05-2117_05_17.093187/model-00022-0.98668-0.62500-0.92351-0.70000.h5
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 3.814697446813398e-09.
# Epoch 23/30
# 8/8 [==============================] - 4s 439ms/step - loss: 0.9353 - categorical_accuracy: 0.6250 - val_loss: 0.8692 - val_categorical_accuracy: 0.6000
#
# Epoch 00023: saving model to model_init_2020-05-2117_05_17.093187/model-00023-0.93529-0.62500-0.86917-0.60000.h5
# Epoch 24/30
# 8/8 [==============================] - 3s 370ms/step - loss: 0.8279 - categorical_accuracy: 0.7083 - val_loss: 1.0360 - val_categorical_accuracy: 0.6000
#
# Epoch 00024: saving model to model_init_2020-05-2117_05_17.093187/model-00024-0.82789-0.70833-1.03604-0.60000.h5
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 1.907348723406699e-09.
# Epoch 25/30
# 8/8 [==============================] - 3s 405ms/step - loss: 0.7840 - categorical_accuracy: 0.5417 - val_loss: 0.8865 - val_categorical_accuracy: 0.6000
#
# Epoch 00025: saving model to model_init_2020-05-2117_05_17.093187/model-00025-0.78400-0.54167-0.88647-0.60000.h5
# Epoch 26/30
# 8/8 [==============================] - 3s 425ms/step - loss: 1.0853 - categorical_accuracy: 0.5833 - val_loss: 0.9669 - val_categorical_accuracy: 0.6500
#
# Epoch 00026: saving model to model_init_2020-05-2117_05_17.093187/model-00026-1.08526-0.58333-0.96687-0.65000.h5
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 9.536743617033494e-10.
# Epoch 27/30
# 8/8 [==============================] - 3s 437ms/step - loss: 1.0661 - categorical_accuracy: 0.6250 - val_loss: 0.8199 - val_categorical_accuracy: 0.6500
#
# Epoch 00027: saving model to model_init_2020-05-2117_05_17.093187/model-00027-1.06611-0.62500-0.81994-0.65000.h5
# Epoch 28/30
# 8/8 [==============================] - 3s 384ms/step - loss: 0.8107 - categorical_accuracy: 0.7083 - val_loss: 0.9652 - val_categorical_accuracy: 0.6500
#
# Epoch 00028: saving model to model_init_2020-05-2117_05_17.093187/model-00028-0.81065-0.70833-0.96523-0.65000.h5
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 4.768371808516747e-10.
# Epoch 29/30
# 8/8 [==============================] - 4s 502ms/step - loss: 1.0159 - categorical_accuracy: 0.4583 - val_loss: 0.8886 - val_categorical_accuracy: 0.7500
#
# Epoch 00029: saving model to model_init_2020-05-2117_05_17.093187/model-00029-1.01589-0.45833-0.88863-0.75000.h5
# Epoch 30/30
# 8/8 [==============================] - 3s 416ms/step - loss: 1.0788 - categorical_accuracy: 0.6250 - val_loss: 0.8789 - val_categorical_accuracy: 0.6500
#
# Epoch 00030: saving model to model_init_2020-05-2117_05_17.093187/model-00030-1.07882-0.62500-0.87894-0.65000.h5
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 2.3841859042583735e-10.

# %% [markdown]
# ### Model - CNN - RNN (LSTM)

# %%
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.layers.recurrent import LSTM

model = Sequential()

model.add(TimeDistributed(Conv2D(16, (3, 3) , padding='same', activation='relu'),
          input_shape=(30,120,120,3)))
model.add(TimeDistributed(BatchNormalization()))

model.add(TimeDistributed(MaxPooling2D((2,2))))

model.add(TimeDistributed(Conv2D(32, (3, 3) , padding='same', activation='relu')))
model.add(TimeDistributed(BatchNormalization()))

model.add(TimeDistributed(MaxPooling2D((2,2))))

model.add(TimeDistributed(Conv2D(64, (3, 3) , padding='same', activation='relu')))
model.add(TimeDistributed(BatchNormalization()))

model.add(TimeDistributed(MaxPooling2D((2,2))))

model.add(TimeDistributed(Conv2D(128, (3, 3) , padding='same', activation='relu')))
model.add(TimeDistributed(BatchNormalization()))

model.add(TimeDistributed(MaxPooling2D((2,2))))

model.add(TimeDistributed(Conv2D(256, (3, 3) , padding='same', activation='relu')))
model.add(TimeDistributed(BatchNormalization()))

model.add(TimeDistributed(MaxPooling2D((2,2))))

#Flatten Layer
model.add(TimeDistributed(Flatten()))

model.add(LSTM(64))
model.add(Dropout(0.5))

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))

#softmax
model.add(Dense(5, activation='softmax'))

# %%
optimiser = Adam() 
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed_5 (TimeDist (None, 30, 120, 120, 16)  448
# _________________________________________________________________
# time_distributed_6 (TimeDist (None, 30, 120, 120, 16)  64
# _________________________________________________________________
# time_distributed_7 (TimeDist (None, 30, 60, 60, 16)    0
# _________________________________________________________________
# time_distributed_8 (TimeDist (None, 30, 60, 60, 32)    4640
# _________________________________________________________________
# time_distributed_9 (TimeDist (None, 30, 60, 60, 32)    128
# _________________________________________________________________
# time_distributed_10 (TimeDis (None, 30, 30, 30, 32)    0
# _________________________________________________________________
# time_distributed_11 (TimeDis (None, 30, 30, 30, 64)    18496
# _________________________________________________________________
# time_distributed_12 (TimeDis (None, 30, 30, 30, 64)    256
# _________________________________________________________________
# time_distributed_13 (TimeDis (None, 30, 15, 15, 64)    0
# _________________________________________________________________
# time_distributed_14 (TimeDis (None, 30, 15, 15, 128)   73856
# _________________________________________________________________
# time_distributed_15 (TimeDis (None, 30, 15, 15, 128)   512
# _________________________________________________________________
# time_distributed_16 (TimeDis (None, 30, 7, 7, 128)     0
# _________________________________________________________________
# time_distributed_17 (TimeDis (None, 30, 7, 7, 256)     295168
# _________________________________________________________________
# time_distributed_18 (TimeDis (None, 30, 7, 7, 256)     1024
# _________________________________________________________________
# time_distributed_19 (TimeDis (None, 30, 3, 3, 256)     0
# _________________________________________________________________
# time_distributed_20 (TimeDis (None, 30, 2304)          0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 64)                606464
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 5)                 325
# =================================================================
# Total params: 1,005,541
# Trainable params: 1,004,549
# Non-trainable params: 992
# _________________________________________________________________
# None

# %% [markdown]
# Let us now fit the CNN-RNN model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
x = 30 #Frame
y = 120 #rows
z = 120 #columns
batch_size = 10
num_epochs = 10
model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/10
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   del sys.path[0]
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:18: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# 8/8 [==============================] - 8s 961ms/step - loss: 1.8830 - categorical_accuracy: 0.2500 - val_loss: 1.6730 - val_categorical_accuracy: 0.2000
#
# Epoch 00001: saving model to model_init_2020-05-2216_46_52.551350/model-00001-1.88298-0.25000-1.67300-0.20000.h5
# Epoch 2/10
# 8/8 [==============================] - 2s 248ms/step - loss: 1.6978 - categorical_accuracy: 0.3750 - val_loss: 1.7438 - val_categorical_accuracy: 0.2000
#
# Epoch 00002: saving model to model_init_2020-05-2216_46_52.551350/model-00002-1.69782-0.37500-1.74383-0.20000.h5
# Epoch 3/10
# 8/8 [==============================] - 3s 340ms/step - loss: 1.7817 - categorical_accuracy: 0.2083 - val_loss: 1.5148 - val_categorical_accuracy: 0.3000
#
# Epoch 00003: saving model to model_init_2020-05-2216_46_52.551350/model-00003-1.78170-0.20833-1.51478-0.30000.h5
# Epoch 4/10
# 8/8 [==============================] - 4s 518ms/step - loss: 1.9327 - categorical_accuracy: 0.3333 - val_loss: 1.6980 - val_categorical_accuracy: 0.2000
#
# Epoch 00004: saving model to model_init_2020-05-2216_46_52.551350/model-00004-1.93269-0.33333-1.69797-0.20000.h5
# Epoch 5/10
# 8/8 [==============================] - 4s 438ms/step - loss: 2.1451 - categorical_accuracy: 0.1250 - val_loss: 1.7562 - val_categorical_accuracy: 0.1000
#
# Epoch 00005: saving model to model_init_2020-05-2216_46_52.551350/model-00005-2.14508-0.12500-1.75619-0.10000.h5
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 6/10
# 8/8 [==============================] - 3s 371ms/step - loss: 1.9788 - categorical_accuracy: 0.2083 - val_loss: 1.5962 - val_categorical_accuracy: 0.1000
#
# Epoch 00006: saving model to model_init_2020-05-2216_46_52.551350/model-00006-1.97879-0.20833-1.59617-0.10000.h5
# Epoch 7/10
# 8/8 [==============================] - 4s 479ms/step - loss: 1.5052 - categorical_accuracy: 0.3750 - val_loss: 1.5921 - val_categorical_accuracy: 0.2500
#
# Epoch 00007: saving model to model_init_2020-05-2216_46_52.551350/model-00007-1.50520-0.37500-1.59205-0.25000.h5
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 8/10
# 8/8 [==============================] - 4s 465ms/step - loss: 1.8796 - categorical_accuracy: 0.1250 - val_loss: 1.6728 - val_categorical_accuracy: 0.1500
#
# Epoch 00008: saving model to model_init_2020-05-2216_46_52.551350/model-00008-1.87960-0.12500-1.67281-0.15000.h5
# Epoch 9/10
# 8/8 [==============================] - 4s 513ms/step - loss: 1.8977 - categorical_accuracy: 0.1250 - val_loss: 1.5442 - val_categorical_accuracy: 0.3000
#
# Epoch 00009: saving model to model_init_2020-05-2216_46_52.551350/model-00009-1.89772-0.12500-1.54419-0.30000.h5
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 10/10
# 8/8 [==============================] - 4s 442ms/step - loss: 1.8024 - categorical_accuracy: 0.2083 - val_loss: 1.6003 - val_categorical_accuracy: 0.4000
#
# Epoch 00010: saving model to model_init_2020-05-2216_46_52.551350/model-00010-1.80242-0.20833-1.60032-0.40000.h5

# %%
batch_size = 90
num_epochs = 30

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/30
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   del sys.path[0]
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:18: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# 8/8 [==============================] - 4s 513ms/step - loss: 1.8501 - categorical_accuracy: 0.1667 - val_loss: 1.6337 - val_categorical_accuracy: 0.3000
#
# Epoch 00001: saving model to model_init_2020-05-2216_46_52.551350/model-00001-1.85007-0.16667-1.63371-0.30000.h5
# Epoch 2/30
# 8/8 [==============================] - 4s 503ms/step - loss: 1.8002 - categorical_accuracy: 0.2500 - val_loss: 1.6096 - val_categorical_accuracy: 0.2500
#
# Epoch 00002: saving model to model_init_2020-05-2216_46_52.551350/model-00002-1.80019-0.25000-1.60961-0.25000.h5
# Epoch 3/30
# 8/8 [==============================] - 3s 425ms/step - loss: 1.6418 - categorical_accuracy: 0.3750 - val_loss: 1.6910 - val_categorical_accuracy: 0.2000
#
# Epoch 00003: saving model to model_init_2020-05-2216_46_52.551350/model-00003-1.64179-0.37500-1.69104-0.20000.h5
# Epoch 4/30
# 8/8 [==============================] - 3s 431ms/step - loss: 1.7279 - categorical_accuracy: 0.2917 - val_loss: 1.6275 - val_categorical_accuracy: 0.2000
#
# Epoch 00004: saving model to model_init_2020-05-2216_46_52.551350/model-00004-1.72788-0.29167-1.62746-0.20000.h5
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 6.776263899889652e-24.
# Epoch 5/30
# 8/8 [==============================] - 3s 432ms/step - loss: 1.5999 - categorical_accuracy: 0.3750 - val_loss: 1.6546 - val_categorical_accuracy: 0.3500
#
# Epoch 00005: saving model to model_init_2020-05-2216_46_52.551350/model-00005-1.59991-0.37500-1.65462-0.35000.h5
# Epoch 6/30
# 8/8 [==============================] - 4s 443ms/step - loss: 1.8682 - categorical_accuracy: 0.1667 - val_loss: 1.5943 - val_categorical_accuracy: 0.2000
#
# Epoch 00006: saving model to model_init_2020-05-2216_46_52.551350/model-00006-1.86821-0.16667-1.59431-0.20000.h5
# Epoch 7/30
# 8/8 [==============================] - 3s 417ms/step - loss: 1.5928 - categorical_accuracy: 0.2500 - val_loss: 1.5913 - val_categorical_accuracy: 0.2500
#
# Epoch 00007: saving model to model_init_2020-05-2216_46_52.551350/model-00007-1.59280-0.25000-1.59126-0.25000.h5
# Epoch 8/30
# 8/8 [==============================] - 3s 432ms/step - loss: 1.6333 - categorical_accuracy: 0.2500 - val_loss: 1.5960 - val_categorical_accuracy: 0.4500
#
# Epoch 00008: saving model to model_init_2020-05-2216_46_52.551350/model-00008-1.63334-0.25000-1.59604-0.45000.h5
# Epoch 9/30
# 8/8 [==============================] - 3s 425ms/step - loss: 1.7621 - categorical_accuracy: 0.3333 - val_loss: 1.6405 - val_categorical_accuracy: 0.1000
#
# Epoch 00009: saving model to model_init_2020-05-2216_46_52.551350/model-00009-1.76211-0.33333-1.64052-0.10000.h5
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 3.388131949944826e-24.
# Epoch 10/30
# 8/8 [==============================] - 4s 472ms/step - loss: 1.9304 - categorical_accuracy: 0.1250 - val_loss: 1.6570 - val_categorical_accuracy: 0.1500
#
# Epoch 00010: saving model to model_init_2020-05-2216_46_52.551350/model-00010-1.93039-0.12500-1.65704-0.15000.h5
# Epoch 11/30
# 8/8 [==============================] - 4s 443ms/step - loss: 1.9742 - categorical_accuracy: 0.1667 - val_loss: 1.6905 - val_categorical_accuracy: 0.2000
#
# Epoch 00011: saving model to model_init_2020-05-2216_46_52.551350/model-00011-1.97420-0.16667-1.69051-0.20000.h5
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 1.694065974972413e-24.
# Epoch 12/30
# 8/8 [==============================] - 3s 424ms/step - loss: 1.7174 - categorical_accuracy: 0.2083 - val_loss: 1.6504 - val_categorical_accuracy: 0.2000
#
# Epoch 00012: saving model to model_init_2020-05-2216_46_52.551350/model-00012-1.71744-0.20833-1.65038-0.20000.h5
# Epoch 13/30
# 8/8 [==============================] - 3s 431ms/step - loss: 1.9479 - categorical_accuracy: 0.0417 - val_loss: 1.5935 - val_categorical_accuracy: 0.2500
#
# Epoch 00013: saving model to model_init_2020-05-2216_46_52.551350/model-00013-1.94788-0.04167-1.59350-0.25000.h5
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 8.470329874862065e-25.
# Epoch 14/30
# 8/8 [==============================] - 4s 501ms/step - loss: 1.8545 - categorical_accuracy: 0.1250 - val_loss: 1.5415 - val_categorical_accuracy: 0.3500
#
# Epoch 00014: saving model to model_init_2020-05-2216_46_52.551350/model-00014-1.85449-0.12500-1.54149-0.35000.h5
# Epoch 15/30
# 8/8 [==============================] - 3s 391ms/step - loss: 1.8194 - categorical_accuracy: 0.1250 - val_loss: 1.6429 - val_categorical_accuracy: 0.3000
#
# Epoch 00015: saving model to model_init_2020-05-2216_46_52.551350/model-00015-1.81938-0.12500-1.64286-0.30000.h5
# Epoch 16/30
# 8/8 [==============================] - 4s 454ms/step - loss: 1.7807 - categorical_accuracy: 0.3333 - val_loss: 1.7511 - val_categorical_accuracy: 0.1000
#
# Epoch 00016: saving model to model_init_2020-05-2216_46_52.551350/model-00016-1.78073-0.33333-1.75114-0.10000.h5
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 4.2351649374310325e-25.
# Epoch 17/30
# 8/8 [==============================] - 3s 418ms/step - loss: 1.9405 - categorical_accuracy: 0.2083 - val_loss: 1.5778 - val_categorical_accuracy: 0.2500
#
# Epoch 00017: saving model to model_init_2020-05-2216_46_52.551350/model-00017-1.94050-0.20833-1.57782-0.25000.h5
# Epoch 18/30
# 8/8 [==============================] - 4s 521ms/step - loss: 1.6141 - categorical_accuracy: 0.1667 - val_loss: 1.6243 - val_categorical_accuracy: 0.2000
#
# Epoch 00018: saving model to model_init_2020-05-2216_46_52.551350/model-00018-1.61408-0.16667-1.62432-0.20000.h5
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 2.1175824687155163e-25.
# Epoch 19/30
# 8/8 [==============================] - 4s 459ms/step - loss: 1.9036 - categorical_accuracy: 0.1667 - val_loss: 1.6427 - val_categorical_accuracy: 0.3500
#
# Epoch 00019: saving model to model_init_2020-05-2216_46_52.551350/model-00019-1.90357-0.16667-1.64268-0.35000.h5
# Epoch 20/30
# 8/8 [==============================] - 3s 388ms/step - loss: 1.7675 - categorical_accuracy: 0.1667 - val_loss: 1.6382 - val_categorical_accuracy: 0.2500
#
# Epoch 00020: saving model to model_init_2020-05-2216_46_52.551350/model-00020-1.76748-0.16667-1.63822-0.25000.h5
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 1.0587912343577581e-25.
# Epoch 21/30
# 8/8 [==============================] - 4s 496ms/step - loss: 1.5620 - categorical_accuracy: 0.2500 - val_loss: 1.6943 - val_categorical_accuracy: 0.2000
#
# Epoch 00021: saving model to model_init_2020-05-2216_46_52.551350/model-00021-1.56199-0.25000-1.69429-0.20000.h5
# Epoch 22/30
# 8/8 [==============================] - 4s 521ms/step - loss: 1.6881 - categorical_accuracy: 0.2083 - val_loss: 1.7367 - val_categorical_accuracy: 0.1500
#
# Epoch 00022: saving model to model_init_2020-05-2216_46_52.551350/model-00022-1.68812-0.20833-1.73674-0.15000.h5
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 5.293956171788791e-26.
# Epoch 23/30
# 8/8 [==============================] - 3s 424ms/step - loss: 1.7932 - categorical_accuracy: 0.2917 - val_loss: 1.6144 - val_categorical_accuracy: 0.2000
#
# Epoch 00023: saving model to model_init_2020-05-2216_46_52.551350/model-00023-1.79319-0.29167-1.61437-0.20000.h5
# Epoch 24/30
# 8/8 [==============================] - 4s 445ms/step - loss: 1.9193 - categorical_accuracy: 0.1667 - val_loss: 1.6225 - val_categorical_accuracy: 0.2500
#
# Epoch 00024: saving model to model_init_2020-05-2216_46_52.551350/model-00024-1.91929-0.16667-1.62247-0.25000.h5
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 2.6469780858943953e-26.
# Epoch 25/30
# 8/8 [==============================] - 4s 439ms/step - loss: 1.7975 - categorical_accuracy: 0.2500 - val_loss: 1.5950 - val_categorical_accuracy: 0.3500
#
# Epoch 00025: saving model to model_init_2020-05-2216_46_52.551350/model-00025-1.79751-0.25000-1.59501-0.35000.h5
# Epoch 26/30
# 8/8 [==============================] - 4s 469ms/step - loss: 2.1184 - categorical_accuracy: 0.1667 - val_loss: 1.6015 - val_categorical_accuracy: 0.3000
#
# Epoch 00026: saving model to model_init_2020-05-2216_46_52.551350/model-00026-2.11838-0.16667-1.60148-0.30000.h5
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 1.3234890429471977e-26.
# Epoch 27/30
# 8/8 [==============================] - 3s 378ms/step - loss: 1.9111 - categorical_accuracy: 0.2083 - val_loss: 1.6260 - val_categorical_accuracy: 0.1500
# Epoch 00027: saving model to model_init_2020-05-2216_46_52.551350/model-00027-1.91114-0.20833-1.62604-0.15000.h5
# Epoch 28/30
# 8/8 [==============================] - 4s 498ms/step - loss: 1.8310 - categorical_accuracy: 0.1250 - val_loss: 1.6205 - val_categorical_accuracy: 0.2500
#
# Epoch 00028: saving model to model_init_2020-05-2216_46_52.551350/model-00028-1.83099-0.12500-1.62052-0.25000.h5
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 6.617445214735988e-27.
# Epoch 29/30
# 8/8 [==============================] - 4s 536ms/step - loss: 1.8814 - categorical_accuracy: 0.1667 - val_loss: 1.5788 - val_categorical_accuracy: 0.3500
#
# Epoch 00029: saving model to model_init_2020-05-2216_46_52.551350/model-00029-1.88137-0.16667-1.57880-0.35000.h5
# Epoch 30/30
# 8/8 [==============================] - 4s 496ms/step - loss: 1.6112 - categorical_accuracy: 0.2917 - val_loss: 1.6672 - val_categorical_accuracy: 0.2000
#
# Epoch 00030: saving model to model_init_2020-05-2216_46_52.551350/model-00030-1.61125-0.29167-1.66718-0.20000.h5
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 3.308722607367994e-27.
